# %%
import pandas as pd
import numpy as np

# Transformaciones que ofrece pandas.
# Se defina como transfomaciones a modificar la estroctura de nuesta DF, por ejemplo: añadirle o quitarle filas u columnas,  

#Traemos las DF
data = pd.read_csv("../data.csv.csv")
data[22:100]

# Como crear una columan nueva.
data["añoMas1"] = data["age"] + "1"
data.head()

# Eliminar una columna.
del(data["añoMas1"])
data.head(100)

# Si queremos eliminar varias columnas a la ves.
data.drop(["pclass", "survived"], axis=1)
# Recordar que si queremos que la modificacion se guarde, tenemos que gardarla en una variable.
data.head()

# Si queremos eliminar filas.
data.drop(0)
data.head()
# Si queremos elinar muchas filas de una sola ves.
data.drop(range(0,12))
data.head(100)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..     ...       ...                                                ...
# 95       1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# 96       1         0                         Douglas, Mr. Walter Donald
# 97       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98       1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 99       1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
#
#        sex     age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# >>> USO DE GROUPBY <<<
data = pd.read_csv("data.csv.csv")
data.head()
data.groupby(by = "sex")["cabin"].describe()
# Out:
#        count unique top freq
# sex
# female   466    104   ?  325
# male     843    133   ?  689
